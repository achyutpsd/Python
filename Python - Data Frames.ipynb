# %%
#Dat Frames using Pandas
import pandas as pd

#Data extractopm

#Method 1 : using full path

stats = pd.read_csv('D:\\Learning\\Datascience\\P4-Demographic-Data.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#Method 2: Change working Directory

# %%
import os

# %%
print(os.getcwd())
# Out:
# D:\Learning\Datascience

# %%
startsread =  pd.read_csv('P4-Demographic-Data.csv')

# %%
startsread
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#Exploring Data

# %%
#No. of Rows
len(stats)
# Out:
# 195

# %%
#Read Columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
len(stats.columns)
# Out:
# 5

# %%
#Top rows
stats.head(6) #by default 5
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
#Bottom Rows
stats.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#Info on the columns
stats.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#stats on the columns
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
#Rename columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['Country Name', 'Country Code', 'Birth Rate', 'Internet Users',
       'Income Group']

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#subsetting dataframes in pands
#1. Rows
stats[10:16]
# Out:
#     Country Name Country Code  Birth Rate  Internet Users         Income Group
# 10    Azerbaijan          AZE      18.300         58.7000  Upper middle income
# 11       Burundi          BDI      44.151          1.3000           Low income
# 12       Belgium          BEL      11.200         82.1702          High income
# 13         Benin          BEN      36.440          4.9000           Low income
# 14  Burkina Faso          BFA      40.551          9.1000           Low income
# 15    Bangladesh          BGD      20.142          6.6300  Lower middle income

# %%
stats[::-10]
# Out:
#              Country Name Country Code  Birth Rate  Internet Users  \
# 194              Zimbabwe          ZWE      35.715         18.5000
# 184         Venezuela, RB          VEN      19.842         54.9000
# 174   Trinidad and Tobago          TTO      14.590         63.8000
# 164             Swaziland          SWZ      30.093         24.7000
# 154          Sierra Leone          SLE      36.729          1.7000
# 144      French Polynesia          PYF      16.393         56.8000
# 134                  Oman          OMN      20.419         66.4500
# 124              Malaysia          MYS      16.805         66.9700
# 114        Macedonia, FYR          MKD      11.222         65.2400
# 104               Lesotho          LSO      28.738          5.0000
# 94               Kiribati          KIR      29.044         11.5000
# 84                Iceland          ISL      13.400         96.5468
# 74   Hong Kong SAR, China          HKG       7.900         74.2000
# ...

# %%
stats['Country Name'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Country Name, dtype: object

# %%
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'Income Group']

# %%
stats.BirthRate.head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
stats[5:10][['BirthRate', 'CountryName']]
# Out:
#    BirthRate          CountryName
# 5     17.716            Argentina
# 6     13.308              Armenia
# 7     16.447  Antigua and Barbuda
# 8     13.200            Australia
# 9      9.400              Austria

# %%
#Data Operations

# %%
results = stats.BirthRate * stats.InternetUsers

# %%
results.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
stats[['CountryCode','BirthRate','InternetUsers']].head()
# Out:
#   CountryCode  BirthRate  InternetUsers
# 0         ABW     10.244           78.9
# 1         AFG     35.253            5.9
# 2         AGO     45.985           19.1
# 3         ALB     12.877           57.2
# 4         ARE     11.044           88.0

# %%
#Add Columns

# %%
stats['resultCol'] = results

# %%
stats[['CountryCode','BirthRate','InternetUsers','resultCol']].head()
# Out:
#   CountryCode  BirthRate  InternetUsers  resultCol
# 0         ABW     10.244           78.9   808.2516
# 1         AFG     35.253            5.9   207.9927
# 2         AGO     45.985           19.1   878.3135
# 3         ALB     12.877           57.2   736.5644
# 4         ARE     11.044           88.0   971.8720

# %%
#Removing a column

# %%
stats= stats.drop('resultCol',1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Filtering Data Frames

# %%
#Fiter by rows

# %%
birthRateFilter = stats.BirthRate >40

# %%
stats[birthRateFilter]B
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#             Income Group
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
internetUserFilter = stats.InternetUsers < 2

# %%
stats[birthRateFilter &  internetUserFilter]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers Income Group
# 11      Burundi         BDI     44.151            1.3   Low income
# 127       Niger         NER     49.661            1.7   Low income
# 156     Somalia         SOM     43.891            1.5   Low income

# %%
MaltaFilter = stats.CountryName == 'Malta'

# %%
stats[MaltaFilter]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers Income Group
# 116       Malta         MLT        9.5        68.9138  High income

# %%
#.at & .iat

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.iat[3,2]
# Out:
# 12.877

# %%
stats.at[3,'BirthRate']
# Out:
# 12.877

# %%
sub10 = stats[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers         Income Group
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10,"CountryName"]
# Out:
# 'Azerbaijan'

# %%
# Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=16,8
import warnings
warnings.filterwarnings('ignore')

# %%
#Distribution

# %%
Viz1 = sns.distplot(stats["InternetUsers"],bins=30)

# %%
#BoxPlot
Viz2 = sns.boxplot(data=stats, x="Income Group", y = "BirthRate")

# %%
# Seaborn gallery

# %%
Viz3 = sns.lmplot(data=stats,x='InternetUsers', y = 'BirthRate',fit_reg=False)

# %%
Viz4 = sns.lmplot(data=stats,x='InternetUsers', y = 'BirthRate',fit_reg=False,\
                 hue='Income Group', size = 10)
